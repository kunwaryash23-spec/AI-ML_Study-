# %%
# !uv pip install openai
# !uv pip install pypdf
# Out:
# Using Python 3.10.20 environment at: d:\Ai engineering course\.venv
# Checked 1 package in 7ms
# Using Python 3.10.20 environment at: d:\Ai engineering course\.venv
# Checked 1 package in 4ms

# %%
from openai import OpenAI
import sys
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import fitz
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline

# %%
import pypdf

pdf_path = (r"D:\Ai engineering course\Day_25\Micro_Syallabus.pdf")

doc = fitz.open(pdf_path)
text = ""
for page in doc :
    text += page.get_text() + "\n"

pattern = r"\[(\d{2}:\d{2}:\d{2}\.\d{2})\]\s*-\s*(.*?)(?=\[\d{2}:\d{2}:\d{2}\.\d{2}\]|$)"


chunk_size = 300
overlap = 30

chunks = []

start = 0
while start<len(text):
    end = start + chunk_size
    chunks.append(text[start:end])
    start += chunk_size - overlap

for i, chunk in enumerate(chunks):
    print(f"\n------Chunk {i}------")
    print(chunk)
# Out:
# ------Chunk 0------
# SAARATHI ACADEMY
# for Digital Excellence
# AI Engineering & Machine Learning
# COURSE BRIEF
# SKILLS & TOOLS YOU WILL MASTER
# Python + scikit-learn
# PyTorch + Transformers
# LangChain + LangGraph
# PC RAG + Pinecone
# AM Agents + Mem0 + MCP
# FastAPI + Docker
# 10 Reasons This Works.
# Why students choose Saarathi - and
#
# ------Chunk 1------
# students choose Saarathi - and how each card helps you ship a real career.
# saarathiacademy.com.np/ai-engineering-and-machine-learning-
# course-in-nepal
# +977-9744442469  ·  +977-
# 9761095364
# TR-10
# 01
# 01
# 02
# 02
# 03
# 03
# 04
# 04
# 05
# 05
# 06
# 06
# 07
# 07
# 08
# 08
# 09
# 09
# 10
# 10
# 10 Max / Batch
# Not 50. Not 30. Ten. Every
# stud
#
# ------Chunk 2------
# ot 50. Not 30. Ten. Every
# student seen, heard, and
# unblocked - every class.
# Sunday
# Open
# Classroom
# Every Sunday the
# classroom
# is
# open. Come in,
# pair-program,
# get unstuck, or
# just focus.
# Day-by-Day
# Syllabus
# Full
# ...

# %%
embedder = make_pipeline(TfidfVectorizer(stop_words = "english"),
                            TruncatedSVD (n_components = 20, random_state = 0),
                             Normalizer ())
index = embedder.fit_transform(chunks)

def retrieve(question, k=3):
    q = embedder.transform([question])[0]
    scores = index @ q
    return [(chunks[i]) for i in np.argsort(-scores)[:k]]

# %%
context = retrieve("what is rag")

# %%
import os



client = OpenAI(
    api_key=os.environ["GEMINI_API_KEY"],   # set in .env / shell — never hardcode
    
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

system_prompt = f"""

You are an expert faq bot. You will review the user's question about certain syllabus topic and its related information.
do not give response in markdown format


I will give you context : {context}
Your output response should be:


Answer in a polite and understandable method so that the user can understand what they are getting in the course and syllabus and also in the end 
promote saarathi academy.

do not answer any question unrelated to our course and simply reject them.



"""
user_query = """

whats 2+2?

"""

response = client.chat.completions.create(
    model="gemini-3.5-flash-lite",
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },

        {
            "role": "user",
            "content": user_query
        }
    ]
)

# %%
ai_response = response.choices[0].message.content

# %%
print(ai_response)
# Out:
# I am sorry, but I can only answer questions related to our course and syllabus. If you have any questions about our curriculum, such as our modules on RAG pipelines, advanced retrieval techniques, or AI development, please feel free to ask!
