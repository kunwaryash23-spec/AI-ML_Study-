# %%
import numpy as np
import pandas as pd

# %%
scores = [10, 20, 30, 40, 50, 60]
print(f"max: {max(scores)}")
mean = sum(scores)/len(scores)
print(f"mean:{mean}")
print(f"above_mean: {[score for score in scores if score > mean]}")
# Out:
# max: 60
# mean:35.0
# above_mean: [40, 50, 60]

# %%
data = {
    "names": ["Priyanka", "Yash", "Charlie", "Saksham", "Eva"],
    "scores": [85, 100, 72, 90, 39]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       names  scores
# 0  Priyanka      85
# 1      Yash     100
# 2   Charlie      72
# 3   Saksham      90
# 4       Eva      39

# %%
mean = sum(scores)/len(scores)
print(mean)
# Out:
# 35.0

# %%
above_score = df[df['scores'] > 70]
print(above_score)
# Out:
#       names  scores
# 0  Priyanka      85
# 1      Yash     100
# 2   Charlie      72
# 3   Saksham      90

# %%
df['passed']= df['scores'] >= 40
print(df)
# Out:
#       names  scores  passed
# 0  Priyanka      85    True
# 1      Yash     100    True
# 2   Charlie      72    True
# 3   Saksham      90    True
# 4       Eva      39   False

# %%
class shape:
    def _init_(self)
        pass
